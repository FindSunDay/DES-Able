# %%
import urllib.request
import pandas as pd
import json

# %%
# where you send a request to.
endpoint = 'https://maps.googleapis.com/maps/api/directions/json?'

# %%
api_key = 'AIzaSyC43uAA_FBmpqw5mcarSzlOs16pwDG6aXs'

# %%
origin = '41.43206,-81.38992'
destination = 'Heathrow'

# %%
nav_request = 'origin=Toronto&destination=Montreal&key=AIzaSyC43uAA_FBmpqw5mcarSzlOs16pwDG6aXs'

# %%
request = endpoint + nav_request
response = urllib.request.urlopen(request).read()

# %%
directions = json.loads(response)
print(directions)
# Out:
# {'geocoded_waypoints': [{'geocoder_status': 'OK', 'place_id': 'ChIJpTvG15DL1IkRd8S0KlBVNTI', 'types': ['locality', 'political']}, {'geocoder_status': 'OK', 'place_id': 'ChIJDbdkHFQayUwR7-8fITgxTmU', 'types': ['locality', 'political']}], 'routes': [{'bounds': {'northeast': {'lat': 45.5018118, 'lng': -73.5640446}, 'southwest': {'lat': 43.6533096, 'lng': -79.3833922}}, 'copyrights': 'Map data ©2020 Google', 'legs': [{'distance': {'text': '541 km', 'value': 541123}, 'duration': {'text': '5 hours 21 mins', 'value': 19288}, 'end_address': 'Montreal, QC, Canada', 'end_location': {'lat': 45.5017123, 'lng': -73.5672184}, 'start_address': 'Toronto, ON, Canada', 'start_location': {'lat': 43.6533096, 'lng': -79.3827656}, 'steps': [{'distance': {'text': '0.3 km', 'value': 280}, 'duration': {'text': '1 min', 'value': 45}, 'end_location': {'lat': 43.6557259, 'lng': -79.3837337}, 'html_instructions': 'Head <b>north</b> on <b>Bay St</b> toward <b>Hagerman St</b>', 'polyline': {'points': 'e`miGhmocNs@
# ...

# %%
dms = pd.read_csv('1.1DMS_Providers_Export_2020_08_20_23_56_29.csv')
ess = pd.read_csv('1.1ESS_Providers_Export_2020_08_20_23_57_16.csv')

# %%
des = pd.read_excel('1.3des-star-ratings-march-2020.xlsx', sheet_name = 'Star Ratings', skiprows= 2)

# %%
des.head()
# Out:
#                              Program     Level Contract ID Org Cd  \
# 0  DES-Disability Management Service  Contract    0212839K   VVFE
# 1  DES-Disability Management Service      Site    0212839K   VVFE
# 2  DES-Disability Management Service      Site    0212839K   VVFE
# 3  DES-Disability Management Service  Contract    0212840D   VVFE
# 4  DES-Disability Management Service      Site    0212840D   VVFE
#
#             Org Name Site Code Site Location ESA Cd              ESA Name  \
# 0  AimBig Employment       NaN           NaN   4CAB  Canterbury/Bankstown
# 1  AimBig Employment      MM37     BANKSTOWN   4CAB  Canterbury/Bankstown
# 2  AimBig Employment      MM27       CAMPSIE   4CAB  Canterbury/Bankstown
# 3  AimBig Employment       NaN           NaN   4CAB  Canterbury/Bankstown
# 4  AimBig Employment      MM37     BANKSTOWN   4CAB  Canterbury/Bankstown
#
#   LMR Sort LMR Name State      Speciality Description Substituted Star Rating  \
# ...

# %%
des['Program'].unique()
# Out:
# array(['DES-Disability Management Service',
#        'DES-Employment Support Service'], dtype=object)

# %%
des_vic = des[des['State'] == 'VIC']
des_vic.shape
# Out:
# (2145, 19)

# %%
dms_vic = dms[dms['State'] == 'VIC']
ess_vic = ess[ess['State'] == 'VIC']

# %%
dms_name = set(zip(dms_vic['Title'], dms_vic['Location']))
ess_name = set(zip(ess_vic['Title'], ess_vic['Location']))

# %%
des_vic
# Out:
#                                 Program     Level Contract ID Org Cd  \
# 1359  DES-Disability Management Service  Contract    0212207A   GGAC
# 1360  DES-Disability Management Service      Site    0212207A   GGAC
# 1361  DES-Disability Management Service      Site    0212207A   GGAC
# 1362  DES-Disability Management Service      Site    0212207A   GGAC
# 1363  DES-Disability Management Service      Site    0212207A   GGAC
# ...                                 ...       ...         ...    ...
# 6672     DES-Employment Support Service      Site    0211206C   PEAW
# 6673     DES-Employment Support Service      Site    0211206C   PEAW
# 6674     DES-Employment Support Service      Site    0211206C   PEAW
# 6675     DES-Employment Support Service      Site    0211206C   PEAW
# 6676     DES-Employment Support Service      Site    0211206C   PEAW
#
#                      Org Name Site Code Site Location ESA Cd     ESA Name  \
# ...

# %%
both = dms_name ^ ess_name

# %%
total = dms_name | ess_name
len(total)
# Out:
# 122

# %%
(set(dms_vic['Title'])|set(ess_vic['Title']))
# Out:
# {'APM Employment Services',
#  'AXIS Employment',
#  'AimBig Employment',
#  'Atwork Australia Pty Ltd',
#  'Campbell Page',
#  'DVJS Employment Solutions',
#  'ECHO',
#  'Job Prospects',
#  'Jobfind Centres Australia Pty Ltd',
#  'MAX Employment',
#  'OCTEC Limited',
#  'Outlook Employment',
#  'Sarina Russo Job Access',
#  'SensWide Services (Expression Australia)',
#  'The Personnel Group Ltd',
#  'WDEA Works',
#  'WISE Employment',
#  'WISE Employment Ltd',
#  'atWork Australia Pty Ltd'}

# %%
intersect = set(des_vic['Org Name']) & (set(dms_vic['Title'])|set(ess_vic['Title']))

# %%
intersect
# Out:
# {'APM Employment Services',
#  'AimBig Employment',
#  'Atwork Australia Pty Ltd',
#  'Campbell Page',
#  'DVJS Employment Solutions',
#  'Job Prospects',
#  'MAX Employment',
#  'Outlook Employment',
#  'Sarina Russo Job Access',
#  'The Personnel Group Ltd',
#  'WDEA Works',
#  'WISE Employment Ltd'}

# %%
des_vic[des_vic['Org Name'].isin(['WISE Employment Ltd'])]
# Out:
#                                 Program     Level Contract ID Org Cd  \
# 1511  DES-Disability Management Service  Contract    0210710K   YAFG
# 1512  DES-Disability Management Service      Site    0210710K   YAFG
# 1513  DES-Disability Management Service      Site    0210710K   YAFG
# 1514  DES-Disability Management Service      Site    0210710K   YAFG
# 1515  DES-Disability Management Service      Site    0210710K   YAFG
# ...                                 ...       ...         ...    ...
# 6637     DES-Employment Support Service  Contract    0211257C   YAFG
# 6638     DES-Employment Support Service      Site    0211257C   YAFG
# 6639     DES-Employment Support Service      Site    0211257C   YAFG
# 6640     DES-Employment Support Service      Site    0211257C   YAFG
# 6641     DES-Employment Support Service      Site    0211257C   YAFG
#
#                  Org Name Site Code Site Location ESA Cd            ESA Name  \
# ...

# %%
ess_vic[ess_vic['Title'].isin({'WISE Employment Ltd'})].shape
# Out:
# (6, 18)

# %%
dms_vic[dms_vic['Title'].isin({'WISE Employment Ltd'})].shape
# Out:
# (0, 18)

# %%
len(des_vic['Org Name'].unique())
